# %%
from pulp import LpMaximize, LpProblem, LpStatus, lpSum, LpVariable

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/python/3.12.1/bin/python

# %%
# Create the model
model = LpProblem(name="small-problem", sense=LpMaximize)

# %%
# Initialize the decision variables
x = LpVariable(name="x", lowBound=0)
y = LpVariable(name="y", lowBound=0)

# %%
expression = 2 * x + 4 * y
type(expression)
# Out:
# pulp.pulp.LpAffineExpression

# %%
constraint = 2 * x + 4 * y >= 8
type(constraint)
# Out:
# pulp.pulp.LpConstraint

# %%
# Add the constraints to the model
model += (2 * x + y <= 20, "red_constraint")
model += (4 * x - 5 * y >= -10, "blue_constraint")
model += (-x + 2 * y >= -2, "yellow_constraint")
model += (-x + 5 * y == 15, "green_constraint")

# %%
# Add the objective function to the model
model += x + 2 * y

# %%
# output the model
model
# Out:
# small-problem:
# MAXIMIZE
# 1*x + 2*y + 0
# SUBJECT TO
# red_constraint: 2 x + y <= 20
#
# blue_constraint: 4 x - 5 y >= -10
#
# yellow_constraint: - x + 2 y >= -2
#
# green_constraint: - x + 5 y = 15
#
# VARIABLES
# x Continuous
# y Continuous

# %%
# Solve the problem
status = model.solve()
status
# Out:
# Welcome to the CBC MILP Solver
# Version: Devel (unstable)
# Build Date: Mar 23 2026
# command line - /tmp/02fb2f6c35334f44ad22847ab38fe7be-pulp.mps -max -timeMode elapsed -solve -printingOptions all -solution /tmp/02fb2f6c35334f44ad22847ab38fe7be-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 20 RHS
# At line 25 BOUNDS
# At line 26 ENDATA
# Problem MODEL has 4 rows, 2 columns and 8 elements
# Coin0008I MODEL read with 0 errors
# Multiple matches for `max'; possible completions:
#   maxF(actor)  maxIt(erations)
# Presolve 0 (-4) rows, 0 (-2) columns and 0 (-8) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 16.818182
# After Postsolve, objective 16.818182, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 16.81818182 - 0 iterations time 0.002, Presolve 0.00
# Total time (Wallclock seconds): 0.00145483   (CPU seconds):             0.002732
# 1

# %%
# more details about the solution
print(model.solver)
print(model.objective.value())

for var in model.variables():
    print(f"{var.name}: {var.value()}")
# Out:
# <pulp.apis.coin_api.COIN_CMD object at 0x7c3c9865ba40>
# 16.8181817
# x: 7.7272727
# y: 4.5454545
